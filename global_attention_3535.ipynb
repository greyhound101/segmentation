# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/Multihead_attention/blob/master/global_attention_3535.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc1=list(np.load('final_accuracy_all_fold1_final_final_3535.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_last_fold2_5e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc3=list(np.load('final_accuracy_all_fold3_final_final_3535.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_final_final_3535.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_last_fold5_5e-4_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9652884635847208

# %%
fnl_acc3=list(np.load('times_all_fold_3_final_final_3535.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_last_fold5_5e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_final_final_3535.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_last_fold2_5e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_final_final_3535.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 9182.52405204773

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_final_final_3535.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_final_final_3535.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[111   1   0]
#  [  2 243   0]
#  [  4   1 180]]

# %%
ans_1=np.load('answers_last_fold2_5e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold2_5e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[153  13   1]
#  [  4 334   0]
#  [  5   3 166]]

# %%
ans_1=np.load('answers_all_fold_3_final_final_3535.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_final_final_3535.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[134   1   4]
#  [ 15 216   0]
#  [  5   0 197]]

# %%
ans_1=np.load('answers_all_fold_4_final_final_3535.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_final_final_3535.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[118   4   2]
#  [  5 320   0]
#  [  3   2 174]]

# %%
ans_1=np.load('answers_last_fold5_5e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold5_5e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[143   5  18]
#  [  9 277   1]
#  [  0   0 190]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('attention.png')

# %%
history={}
history['fold1']=np.load('history_all_fold_1_final_final_3535.npy',allow_pickle=True).item()
history['fold2']=np.load('history_last_fold2_5e-4_wn.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_final_final_3535.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_final_final_3535.npy',allow_pickle=True).item()
history['fold5']=np.load('history_last_fold5_5e-4_wn.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
