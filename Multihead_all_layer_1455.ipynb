# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/Multihead_attention/blob/master/Multihead_all_layer_1455.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc1=list(np.load('final_accuracy_last_fold1_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_final_final_1455.npy',allow_pickle=True).item().values())[0]
fnl_acc3=list(np.load('final_accuracy_last_fold3_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_last_fold4_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_last_fold5_1e-3_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9641917793291974

# %%
fnl_acc3=list(np.load('times_last_fold3_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_last_fold5_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_last_fold4_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_final_final_1455.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_last_fold1_1e-3_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 25448.007854270934

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[111   1   0]
#  [  2 243   0]
#  [ 10   2 173]]

# %%
ans_1=np.load('answers_all_fold_2_final_final_1455.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_final_final_1455.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[155  11   1]
#  [  2 335   1]
#  [  5   7 162]]

# %%
ans_1=np.load('answers_last_fold3_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold3_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[136   3   0]
#  [ 11 220   0]
#  [  4   0 198]]

# %%
ans_1=np.load('answers_last_fold4_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold4_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[110  11   3]
#  [  1 323   1]
#  [  6   0 173]]

# %%
ans_1=np.load('answers_last_fold5_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold5_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[145   4  17]
#  [  6 281   0]
#  [  1   1 188]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('attention.png')

# %%
history={}
history['fold1']=np.load('history_last_fold1_1e-3_wn.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_final_final_1455.npy',allow_pickle=True).item()
history['fold3']=np.load('history_last_fold3_1e-3_wn.npy',allow_pickle=True).item()
history['fold4']=np.load('history_last_fold4_1e-3_wn.npy',allow_pickle=True).item()
history['fold5']=np.load('history_last_fold5_1e-3_wn.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
