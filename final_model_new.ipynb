# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/data/blob/master/final_model_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_last_fold3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_last_fold5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_last_fold4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9165352280510778

# %%
fnl_acc3=list(np.load('times_last_fold3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_last_fold5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_last_fold4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 2302.535823726654

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 99  13   0]
#  [ 11 234   0]
#  [ 17   1 167]]

# %%
ans_1=np.load('answers_last_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[126  21  20]
#  [  9 322   7]
#  [  5   7 162]]

# %%
ans_1=np.load('answers_last_fold3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[123   9   7]
#  [ 11 219   1]
#  [  2   3 197]]

# %%
ans_1=np.load('answers_last_fold4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[104  14   6]
#  [ 11 308   6]
#  [  5   3 171]]

# %%
ans_1=np.load('answers_last_fold5_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold5_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[122  18  26]
#  [ 21 266   0]
#  [  2   3 185]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('final.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
history={}
history['fold1']=np.load('history_last_fold1_wn.npy',allow_pickle=True).item()
history['fold2']=np.load('history_last_fold2_wn.npy',allow_pickle=True).item()
history['fold3']=np.load('history_last_fold3_wn.npy',allow_pickle=True).item()
history['fold4']=np.load('history_last_fold4_wn.npy',allow_pickle=True).item()
history['fold5']=np.load('history_last_fold5_wn.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
