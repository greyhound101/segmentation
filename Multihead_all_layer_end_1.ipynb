# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/Multihead_attention/blob/master/Multihead_all_layer_end_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
path='/content/'
fnl_acc3=list(np.load(path+'final_accuracy_all_fold1_final_3_final.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load(path+'final_accuracy_all_fold2_final_3_final-6.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load(path+'final_accuracy_all_fold3_final_3_final2.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load(path+'final_accuracy_last_fold4_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load(path+'final_accuracy_all_fold5_final_3_final2.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9625435034305966

# %%
fnl_acc3=list(np.load(path+'times_all_fold_3_final_3_final2.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load(path+'times_all_fold_5_final_3_final2.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load(path+'times_last_fold4_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load(path+'times_all_fold_2_final_3_final-6.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load(path+'times_all_fold_1_final_3_final.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 20327.866192770005

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load(path+'answers_all_fold_1_final_3_final.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_all_fold_1_final_3_final.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[111   1   0]
#  [  8 237   0]
#  [  4   1 180]]

# %%
ans_1=np.load(path+'answers_all_fold_2_final_3_final-6.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_all_fold_2_final_3_final-6.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[152  15   0]
#  [  1 337   0]
#  [  7  11 156]]

# %%
ans_1=np.load(path+'answers_all_fold_3_final_3_final2.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_all_fold_3_final_3_final2.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[135   3   1]
#  [ 11 218   2]
#  [  1   0 201]]

# %%
ans_1=np.load(path+'answers_last_fold4_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_last_fold4_1e-3_wn (6).npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[113   6   5]
#  [  0 323   2]
#  [  0   3 176]]

# %%
ans_1=np.load(path+'answers_all_fold_5_final_3_final2.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_all_fold_5_final_3_final2.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[142   4  20]
#  [  7 279   1]
#  [  1   2 187]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('mobilenet.png')

# %%
history={}
history['fold1']=np.load(path+'history_all_fold_1_final_3_final.npy',allow_pickle=True).item()
history['fold2']=np.load(path+'history_all_fold_2_final_3_final-6.npy',allow_pickle=True).item()
history['fold3']=np.load(path+'history_all_fold_3_final_3_final2.npy',allow_pickle=True).item()
history['fold4']=np.load(path+'history_last_fold4_1e-3_wn.npy',allow_pickle=True).item()
history['fold5']=np.load(path+'history_all_fold_5_final_3_final2.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
