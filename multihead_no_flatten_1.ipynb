# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/Multihead_attention/blob/master/multihead_no_flatten_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
path='/content/'
fnl_acc3=list(np.load(path+'final_accuracy_last_fold1_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load(path+'final_accuracy_last_fold2_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load(path+'final_accuracy_last_fold3_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load(path+'final_accuracy_last_fold4_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load(path+'final_accuracy_last_fold5_1e-3_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9677988183666069

# %%
fnl_acc3=list(np.load(path+'times_last_fold3_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load(path+'times_last_fold5_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load(path+'times_last_fold4_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load(path+'times_last_fold2_1e-3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load(path+'times_last_fold1_1e-3_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 16985.92666835785

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load(path+'answers_last_fold1_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_last_fold1_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[111   1   0]
#  [  1 244   0]
#  [  8   0 177]]

# %%
ans_1=np.load(path+'answers_last_fold2_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_last_fold2_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[157  10   0]
#  [  1 335   2]
#  [  2  10 162]]

# %%
ans_1=np.load(path+'answers_last_fold3_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_last_fold3_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[134   4   1]
#  [ 14 217   0]
#  [  2   0 200]]

# %%
ans_1=np.load(path+'answers_last_fold4_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_last_fold4_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[114   6   4]
#  [  2 323   0]
#  [  3   1 175]]

# %%
ans_1=np.load(path+'answers_last_fold5_1e-3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load(path+'predictions_last_fold5_1e-3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[145   1  20]
#  [  6 280   1]
#  [  0   0 190]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('mobilenet.png')

# %%
history={}
history['fold1']=np.load(path+'history_last_fold1_1e-3_wn.npy',allow_pickle=True).item()
history['fold2']=np.load(path+'history_last_fold2_1e-3_wn.npy',allow_pickle=True).item()
history['fold3']=np.load(path+'history_last_fold3_1e-3_wn.npy',allow_pickle=True).item()
history['fold4']=np.load(path+'history_last_fold4_1e-3_wn.npy',allow_pickle=True).item()
history['fold5']=np.load(path+'history_last_fold5_1e-3_wn.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
